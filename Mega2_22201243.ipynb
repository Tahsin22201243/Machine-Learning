# %% [markdown]
# <a href="https://colab.research.google.com/github/Tahsin22201243/Machine-Learning/blob/main/Mega2_22201243.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer, load_iris
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score,precision_score,recall_score,f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %% [markdown]
# **Part A**

# %%
# Qns 1 Load dataset
data = load_breast_cancer()
x,y = data.data, data.target

# Qns 2  Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(
    x, y,
    test_size=0.2,
    random_state=42,

)

# %%
# Train model
dt = DecisionTreeClassifier(max_depth=5,random_state=42)
knn = KNeighborsClassifier(n_neighbors=5)
dt.fit(X_train, y_train)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_dt = dt.predict(X_test)
y_pred_knn = knn.predict(X_test)

# %%
#Qns 4
def evaluate (y_true,y_pred,model_name):
    print(model_name)
    print("Precision",precision_score(y_true,y_pred))
    print("Recall",recall_score(y_true,y_pred ))
    print("F1 Score",f1_score(y_true,y_pred))
    print("Accuracy",accuracy_score(y_true,y_pred))
    print("Confusion Matrix")
    print(confusion_matrix(y_true,y_pred))

evaluate(y_test, y_pred_dt, "Decision Tree")
evaluate(y_test, y_pred_knn, "KNN")
# Out:
# Decision Tree
# Precision 0.9577464788732394
# Recall 0.9577464788732394
# F1 Score 0.9577464788732394
# Accuracy 0.9473684210526315
# Confusion Matrix
# [[40  3]
#  [ 3 68]]
# KNN
# Precision 0.9342105263157895
# Recall 1.0
# F1 Score 0.9659863945578231
# Accuracy 0.956140350877193
# Confusion Matrix
# [[38  5]
#  [ 0 71]]

# %% [markdown]
# Qns6: KNN performs slightly better than Decision Tree with higher accuracy and fewer misclassifications,but decision tree is faster and easier to interpret

# %%
#Qns 5
print("Decision Tree")
print(classification_report(y_test,y_pred_dt))
print("KNN")
print(classification_report(y_test,y_pred_knn))
# Out:
# Decision Tree
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93        43
#            1       0.96      0.96      0.96        71
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
#
# KNN
#               precision    recall  f1-score   support
#
#            0       1.00      0.88      0.94        43
#            1       0.93      1.00      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.94      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# Part B Qns 2

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
import numpy as np


svm = SVC(kernel='rbf')


CV_scores = cross_val_score(
    svm, x,
    y,
    cv=5,
    scoring='accuracy'
    )


print("All 5 scores:", CV_scores)
print("Mean accuracy:", np.mean(CV_scores))
print("Standard deviation:", np.std(CV_scores))


svm.fit(X_train, y_train)
test_acc = svm.score(X_test, y_test)

print("Test Accuracy:", test_acc)
# Out:
# All 5 scores: [0.85087719 0.89473684 0.92982456 0.94736842 0.9380531 ]
# Mean accuracy: 0.9121720229777983
# Standard deviation: 0.03544367440584207
# Test Accuracy: 0.9473684210526315
